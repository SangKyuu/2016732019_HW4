# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone "https://github.com/SangKyuu/2016732019_HW4"
# Out:
# Cloning into '2016732019_HW4'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
cd 2016732019_HW4/
# Out:
# /content/drive/My Drive/Colab Notebooks/2016732019_HW4

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/2016732019_HW4/.git/

# %%
# !git config --global user.email "khlim258@gmail.com"
# !git config --global user.name "SangKyuu"

# %%
# !cat README.md
# Out:
# # 2016732019_HW4
#
#
# # HELLOW WORLD
#
# # this is homework 4

# %%
# !git checkout -b branchpr
# Out:
# Switched to a new branch 'branchpr'

# %%
# !cat README.md
# Out:
# # 2016732019_HW4
#
#
# # HELLOW WORLD
#
# # this is homework 4
#
# ## change on branch pr

# %%
# !git add .
# !git commit -m "Edit Readme.md"
# Out:
# [branchpr f14bcfd] Edit Readme.md
#  1 file changed, 3 insertions(+), 1 deletion(-)

# %%
# !git log
# Out:
# commit f14bcfd151b33bd78fff11509e8a2f7aa8983317 (HEAD -> branchpr)
# Author: SangKyuu <khlim258@gmail.com>
# Date:   Sun Sep 26 07:11:48 2021 +0000
#
#     Edit Readme.md
#
# commit 9e99498134e38005f8dd8a9b43fca4d3df69d9f5 (2016732019_HW4/main, main)
# Author: SangKyuu <khlim258@gmail.com>
# Date:   Sun Sep 26 06:55:50 2021 +0000
#
#     Edit Readme.md
#
# commit 5d4c82967e3e25e1c4024e4b4f2696470ad0486c
# Author: SangKyuu <41942097+SangKyuu@users.noreply.github.com>
# Date:   Sun Sep 26 15:46:13 2021 +0900
#
#     Initial commit

# %%
# !git push -u 2016732019_HW4 branchpr
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 321 bytes | 107.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'branchpr' on GitHub by visiting:
# remote:      https://github.com/SangKyuu/2016732019_HW4/pull/new/branchpr
# remote:
# To https://github.com/SangKyuu/2016732019_HW4.git
#  * [new branch]      branchpr -> branchpr
# Branch 'branchpr' set up to track remote branch 'branchpr' from '2016732019_HW4'.

# %%
# !git branch -a
# Out:
# * branchpr
#   main
#   remotes/2016732019_HW4/branchpr
#   remotes/2016732019_HW4/main

# %%
# !git checkout main
# !git merge branchpr
# Out:
# Switched to branch 'main'
# Your branch is up to date with '2016732019_HW4/main'.
# Updating 9e99498..f14bcfd
# Fast-forward
#  README.md | 4 +++-
#  1 file changed, 3 insertions(+), 1 deletion(-)

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of '2016732019_HW4/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push -u 2016732019_HW4 main
# Out:
# Total 0 (delta 0), reused 0 (delta 0)
# To https://github.com/SangKyuu/2016732019_HW4.git
#    9e99498..f14bcfd  main -> main
# Branch 'main' set up to track remote branch 'main' from '2016732019_HW4'.

# %%
cd ../
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git clone "https://github.com/SangKyuu/HW4"
# Out:
# Cloning into 'HW4'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
cd ./HW4
# Out:
# /content/drive/My Drive/Colab Notebooks/HW4

# %%
# !git checkout -b branch_pr_2016732019
# Out:
# Switched to a new branch 'branch_pr_2016732019'

# %%
# !cat README.md
# Out:
# # HW4

# %%
#수정 후
# !cat README.md
# Out:
# # HW4
#
#
# # modified bt 2016732019

# %%
# !git add ./
# !git commit -m '2016732019'
# Out:
# [branch_pr_2016732019 9bd213c] 2016732019
#  1 file changed, 3 insertions(+)

# %%
# !git remote add HW4 https://SangKyuu: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@github.com/SangKyuu/HW4.git

# %%
# !git push -u HW4 branch_pr_2016732019
# Out:
# Counting objects: 3, done.
# Writing objects: 100% (3/3), 273 bytes | 91.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'branch_pr_2016732019' on GitHub by visiting:
# remote:      https://github.com/SangKyuu/HW4/pull/new/branch_pr_2016732019
# remote:
# To https://github.com/SangKyuu/HW4.git
#  * [new branch]      branch_pr_2016732019 -> branch_pr_2016732019
# Branch 'branch_pr_2016732019' set up to track remote branch 'branch_pr_2016732019' from 'HW4'.
