# %%
print('Hello World')
# Out:
# Hello World

# %%
def helloworld():
  print('Hello World')

helloworld()
# Out:
# Hello World

# %%
print('start')
for i in range(10):
  if i > 5:
    print(f'i = {i} > 5')
  elif i<5:
    print(f'i = {i} < 5')
  else:
    print(f'i = {i} = 5')

print('end')
# Out:
# start
# i = 0 < 5
# i = 1 < 5
# i = 2 < 5
# i = 3 < 5
# i = 4 < 5
# i = 5 = 5
# i = 6 > 5
# i = 7 > 5
# i = 8 > 5
# i = 9 > 5
# end

# %%
def function():
  print('function start')
  print('function end')

print('script start')
function()
print('script end')
# Out:
# script start
# function start
# function end
# script end

# %%
a = input()
print(a)
# Out:
# 1
# 1

# %%
i = 4
j = 4.5
k = 'abc'

print(f'i = {i}, j = {j}, k = {k}')
# Out:
# i = 4, j = 4.5, k = abc

# %%
name = input('What is your name?')
age = input('How old are you?')
grade = input('What is your grade point average?')


print('Your name is %s' % name)
print('Your age is %s' % age)
print('Your grade is %s' % grade)
# Out:
# What is your name?Kim
# How old are you?20
# What is your grade point average?40.5
# Your name is Kim
# Your age is 20
# Your grade is 40.5
